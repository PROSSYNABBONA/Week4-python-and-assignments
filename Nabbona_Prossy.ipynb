# %%
import numpy as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set the option to display all rows
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
sns.set(style="darkgrid", rc={"axes.facecolor":"#CAF1DE"})

# %%
#Data preprocessing

# %%
df4=pd.read_csv('bse_dataset4.csv')
df4
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5                    NaN         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
df4.shape
# Out:
# (169, 15)

# %%
df4.columns
# Out:
# Index(['Timestamp', 'gender', 'Age', 'emotion', 'YOB', 'CGPA',
#        'Do you have a Girl Friend or BOY Friend', 'Do you have Depression?',
#        'Do you have Anxiety?', 'Do you have Panic attack?',
#        'Did you have seek any specialist for a treatment? ', 'Duration',
#        'Pulse', 'Maxpulse', 'Calories'],
#       dtype='object')

# %%
#Dropping empty rows 
df4_new=df4.dropna()
df4_new
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# 13   05/07/2023 09:39:40           MALE  22.0                  fine
# ...

# %%
# df4=df4.dropna(inplace=True)
# df4

# %%
df4.fillna(value=100,inplace=True)
df4
# Out:
#                Timestamp         gender    Age               emotion  \
# 0    05/07/2023 09:38:39           Male   21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock   45.0                 Weird
# 2    05/07/2023 09:39:09        Female    20.0                 Happy
# 3    05/07/2023 09:39:12           Male   21.0                 Happy
# 4    05/07/2023 09:39:14         Female   21.0                 Happy
# 5                    100         Female   23.0                Happy
# 6    05/07/2023 09:39:21         female   21.0            irritated
# 7    05/07/2023 09:39:23        Female    22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male   22.0                   Sad
# 9    05/07/2023 09:39:27         Female   20.0                 happy
# 10            2023/12/26           Male   24.0                 Happy
# 11   05/07/2023 09:39:27         Female   20.0                 happy
# 12   05/07/2023 09:39:38           Male   25.0                 Happy
# ...

# %%
df4['Calories'].fillna(100, inplace=True)
df4
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
print(df4.to_string())
# Out:
#                Timestamp         gender    Age               emotion            YOB              CGPA Do you have a Girl Friend or BOY Friend Do you have Depression? Do you have Anxiety? Do you have Panic attack? Did you have seek any specialist for a treatment?   Duration  Pulse  Maxpulse  Calories
# 0    05/07/2023 09:38:39           Male   21.0               Content           2002              4.22                                      No                      No                  Yes                       Yes                                                Yes        60    110       130     409.1
# 1    05/07/2023 09:38:57  Marabou stock   45.0                 Weird           2100               8.9                                     Yes                     Yes                  Yes                       Yes                                                 No        60    117       145     479.0
# ...

# %%
#using mean to get calories
#Replace using mean,medium,mode
#calculating mean
m=df4['Calories'].mean()
df4['Calories'].fillna(m,inplace=True)

# %%
print(df4.to_string())
# Out:
#                Timestamp         gender    Age               emotion            YOB              CGPA Do you have a Girl Friend or BOY Friend Do you have Depression? Do you have Anxiety? Do you have Panic attack? Did you have seek any specialist for a treatment?   Duration  Pulse  Maxpulse  Calories
# 0    05/07/2023 09:38:39           Male   21.0               Content           2002              4.22                                      No                      No                  Yes                       Yes                                                Yes        60    110       130     409.1
# 1    05/07/2023 09:38:57  Marabou stock   45.0                 Weird           2100               8.9                                     Yes                     Yes                  Yes                       Yes                                                 No        60    117       145     479.0
# ...

# %%
#Empty cells,Wrong formats,wrong data,duplicates
#duplicates(core od data preparation and preprocessing)
#calculate median(middle number)
df4=pd.read_csv('bse_dataset4.csv')
med=df4['Calories'].median()
df4['Calories'].fillna(med,inplace=True)
df4
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5                    NaN         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
print(med)
# Out:
# 318.6

# %%
# Exercise:calculating mode
mod=df4['Age'].mode()
df4['Age'].fillna(mod,inplace=True)
df4
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5                    NaN         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
print(mod)
# Out:
# 0    21.0
# Name: Age, dtype: float64

# %%
#Wrong format are rows that are hard to analyze eg 20230705 convert to 2023/07/05
#Row 5 contained NaN values and we filled with
df4=pd.read_csv('bse_dataset4.csv')
df4["Timestamp"].fillna("05/07/2023 09:45:13", inplace=True)
df4
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5    05/07/2023 09:45:13         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
#try out to_datetime()

# %%
df4["Timestamp"].fillna("05/07/2023 09:45:13",inplace=True)
df4
# Out:
#                Timestamp         gender   Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.0               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09        Female   20.0                 Happy
# 3    05/07/2023 09:39:12           Male  21.0                 Happy
# 4    05/07/2023 09:39:14         Female  21.0                 Happy
# 5    05/07/2023 09:45:13         Female  23.0                Happy
# 6    05/07/2023 09:39:21         female  21.0            irritated
# 7    05/07/2023 09:39:23        Female   22.0  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.0                   Sad
# 9    05/07/2023 09:39:27         Female  20.0                 happy
# 10            2023/12/26           Male  24.0                 Happy
# 11   05/07/2023 09:39:27         Female  20.0                 happy
# 12   05/07/2023 09:39:38           Male  25.0                 Happy
# ...

# %%
#Wrong data
#it occurs wen some value goes beyond a specified
#eg age of 23 and u write 23000 so we comment row 23,37 contained typo in data 23,2300 typo,we changed from 2300 to 23
#or 2999 and u write 29.99

for x in df4.index:
    if df4.loc[x,"gender"]=="Marabou stock":
     df4.drop(x,inplace=True)
     df4

# %%
#duplicates
print(df4.duplicated())
# Out:
# 0      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# ...

# %%
df4.drop_duplicates(inplace=True)

# %%
print(df4.duplicated())
# Out:
# 0      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# 30     False
# 31     False
# 32     False
# 33     False
# 34     False
# 35     False
# 36     False
# 37     False
# 38     False
# 39     False
# 40     False
# 41     False
# 42     False
# 43     False
# 44     False
# 45     False
# 46     False
# 47     False
# 48     False
# 49     False
# 50     False
# 51     False
# 52     False
# 53     False
# 54     False
# 55     False
# 56     False
# 57     False
# 58     False
# 59     False
# 60     False
# 61     False
# 62     False
# 63     False
# 64     False
# 65     False
# 66     False
# 67     False
# ...

# %%
#plotting Data visualization(Heat map,pie chart,bargraph,line graph ,line plot,dotted dashed)
#scatterplot library,histogram)
import matplotlib.pyplot as plt
#1.histogram
df4['Age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#pie chart
df4['Age'].plot(kind='pie')
# Out:
# <Axes: ylabel='Age'>

# %%
df4['Age'].plot(kind='bar')
# Out:
# <Axes: >
